# %% [markdown]
# ## Week1: Day1

# %% [markdown]
# ### Complete Pre-reading tasks
#
# - Representational State Application Programming Interface (REST)
#     - To know about history of REST APIs read: [History of APIs](http://apievangelist.com/2012/12/20/history-of-apis/)
#     - Want to know more, watch this short video to gain more understanding: [REST API concepts and examples](https://www.youtube.com/watch?v=7YcW25PHnAA)
#
#
# - Document Object Model (DOM)
#     - Basics of DOM: [What is the Document Object Model](https://www.w3.org/TR/WD-DOM/introduction.html)
#     - Want a more detailed description: [Coding 101: An introduction to DOM](https://medium.com/adventures-in-codeland/coding-101-an-introduction-to-the-document-object-model-8b143ca86a84)
#
#
# - Hyper Text Markup Language (HTML)
#     - Introduction to HTML: [Intro](https://www.w3schools.com/html/html_intro.asp)
#     - Watch this video for a fun, short understanding: [HTML](https://www.youtube.com/watch?v=4A2mWqLUpzw&t=219s)
#
#
# - XML
#     - [Basics of XML](https://www.sitepoint.com/really-good-introduction-xml/)
#     - [Bonus Reading: XPath Introduction](https://www.skillbuilders.com/Tutorials-V2/ads-wrapper.cfm?content=xml_XPATH/XML_XPath.cfm&title=Introduction%20to%20XML%20Tutorial%20%7C%20XPath%20Basics)
#
#
# - Javascript Object Notation (JSON)
#     - [JSON in a Nutshell](https://medium.com/omarelgabrys-blog/json-in-a-nutshell-7d638dfea7cc)
#
#
# - Yet Another Markup Language (YAML)
#     - [YAML Wiki](https://en.wikipedia.org/wiki/YAML)
#
#
# - CRISP-DM
#     - [CRISP-DM and why should you know about it](https://www.r-bloggers.com/crisp-dm-and-why-you-should-know-about-it/)

# %% [markdown]
# ### Pre-Class activity 1:
#
# __Setting up a "Twitter" account, get the tokens, set up the tokens.__
#
#
# - All we need to do is visit this page: [Twitter](https://twitter.com/signup?lang=en) and fill in the details to sign up! (_Note: No need to do this if you already are a Twitterati!_)
#
# - Next step is to get to the Twitter Application Management page: [Twitter Applicaition Management](https://apps.twitter.com/)
#
# - Sign in with the credentials that you used to create your Twitter Id.
#
# - Below is the homepage that you'll see. It won't have any applications, so click on _Create New Apps_.
#
# <br>
# <div align="center"><img src="./images/twitter1.png"/></div>
#
# - It would take you to the _Create an application_ page. (_see below_)
#
# <br>
# <div align="center"><img src="./images/twitter2.png"/></div>
#
# - Fill up all the details and click on _Create Application_, you'll be redirected to the app management page. (_See below_)
#
# <br>
# <div align="center"><img src="./images/twitter3.png"/></div>
#
#
# - Click on the _Keys and Access Tokens_ tab, you would see two sections:
#     * Application Settings
#     * Your Access Token
#
#
# - _Application Settings_ has the tokens that the application needs to authenticate your api call against.
#
# <br>
# <div align="center">
# <img src="./images/twitter4.png"/>
# </div>
#
# - _Access Tokens_ need to be created for a freshly minted Twitter app. So go on and click the _Create my access token_.
#
# <br>
# <div align="center">
# <img src="./images/twitter5.png"/>
# </div>
#
# - You are now set to use it for exciting applications!

# %% [markdown]
# __Setup a Github account, get the tokens, setup the tokens__
#
# - Visit the website: [Github](https://github.com/)
# - Click on _Sign up_ and fill out all the details in __Step 1: Set up a personal account__, get yourself a cool github id! (_Note: You can choose to continue with your previous id, if you had one).
#
# - __Step 2: Choose your plan__, let the default be _Unlimited public repositories for free_ and click on _Continue_
#
# - __Step 3: Tailor your experience__, fill in the details (_or you could skip this_).
#
# - If you are new to the whole Github experience, feel free to read the guide or explore. (_see below_)
#
# <br>
# <div align="center">
# <img src="./images/github1.png"/>
# </div>
#
# - Click on _Settings_ and scroll-down to find _Developer settings_.
#
# <br>
# <div align="center">
# <img src="./images/github2.png"/>
# </div>
#
# - Register a new application, that would take you to the page below:
#
# <br>
# <div align="center">
# <img src="./images/github3.png"/>
# </div>
#
# - Fill in the details, just the same as while creating a Twitter app, and register your application.
#
# - Your `Client ID` and `Client Secret` are now created for the demo application. (_see below_)
#
# <br>
# <div align="center">
# <img src="./images/github4.png"/>
# </div>

# %% [markdown]
# ### Pre-class activity 2:
#
#
# __Get YAML data file from Cricsheet__
#
# > [Cricsheet](http://cricsheet.org/) is a freely available structured ball-by-ball data for international and IPL cricket matches.
#
# - Visit their website to download the data from the links, download a particular: [IPL Dataset: 580 Matches](http://cricsheet.org/downloads/ipl.zip).
# - Extract all the data (everything would be in `*.yml` format).
# - We are now all set!
